# %% [markdown]
# # MDAnalysis 2.1.0

# %% [markdown]
# ## Load into MDAnalysis Universe

# %%
import numpy as np
import pandas as pd
import MDAnalysis as mda
import psutil

# %%
np.__version__
# Out:
# '1.22.4'

# %%
pd.__version__
# Out:
# '2.1.0'

# %%
mda.__version__
# Out:
# '2.6.1'

# %%
psutil.__version__
# Out:
# '5.9.0'

# %%
tprfile = "data/molecules.prmtop"
trrfile = "data/data.trr"
u=mda.Universe(tprfile, trrfile)

# %%
tprfile
# Out:
# 'data/molecules.prmtop'

# %%
from CodeEntropy.ClassCollection.PoseidonClass import Poseidon
poseidon_object = Poseidon(container=u, start =0, end =20)
# Out:
# 2023-09-14 10:19:30.199277
# frame = 0
# < Timestep 0 with unit cell dimensions [30.67833  30.40052  29.490604 90.       90.       90.      ] >
# 0:00:01.495985
# frame = 1
# < Timestep 1 with unit cell dimensions [30.682182 30.404337 29.494312 90.       90.       90.      ] >
# 0:00:02.611287
# frame = 2
# < Timestep 2 with unit cell dimensions [30.713255 30.435127 29.524178 90.       90.       90.      ] >
# 0:00:03.782493
# frame = 3
# < Timestep 3 with unit cell dimensions [30.598316 30.321232 29.41369  90.       90.       90.      ] >
# 0:00:04.866168
# frame = 4
# < Timestep 4 with unit cell dimensions [30.618622 30.341354 29.43321  90.       90.       90.      ] >
# 0:00:06.046217
# frame = 5
# < Timestep 5 with unit cell dimensions [30.619095 30.341824 29.433666 90.       90.       90.      ] >
# 0:00:07.225655
# frame = 6
# < Timestep 6 with unit cell dimensions [30.738136 30.459784 29.5481   90.       90.       90.      ] >
# 0:00:08.386081
# frame = 7
# < Timestep 7 with unit cell dimensions [30.694881 30.416918 29.506514 90.       90.       90.      ] >
# 0:00:09.498115
# frame = 8
# < Timestep 8 with unit cell dimensions [30.644718 30.36721  29.458292 90.       90.       90.      ] >
# 0:00:10.594776
# frame = 9
# < Timestep 9 with unit cell dimensions [30.726116 30.447872 29.536541 90.       90.       90.      ] >
# 0:00:11.783675
# frame = 10
# < Timestep 10 with unit cell dimensions [30.580582 30.303658 29.39664  90.       90.       90.      ] >
# 0:00:12.900159
# frame = 11
# < Timestep 11 with unit cell dimensions [30.772951 30.494282 29.581562 90.       90.       90.      ] >
# 0:00:13.994537
# frame = 12
# < Timestep 12 with unit cell dimensions [30.772266 30.493605 29.580906 90.       90.       90.      ] >
# 0:00:15.159359
# frame = 13
# < Timestep 13 with unit cell dimensions [30.58512  30.308151 29.401005 90.       90.       90.      ] >
# 0:00:16.241680
# frame = 14
# < Timestep 14 with unit cell dimensions [30.599762 30.322662 29.415077 90.       90.       90.      ] >
# 0:00:17.381986
# frame = 15
# < Timestep 15 with unit cell dimensions [30.746477 30.468048 29.556114 90.       90.       90.      ] >
# 0:00:18.592023
# frame = 16
# < Timestep 16 with unit cell dimensions [30.764982 30.486385 29.573902 90.       90.       90.      ] >
# 0:00:19.938002
# frame = 17
# < Timestep 17 with unit cell dimensions [30.672724 30.394962 29.485216 90.       90.       90.      ] >
# 0:00:21.122983
# frame = 18
# < Timestep 18 with unit cell dimensions [30.674246 30.396471 29.48668  90.       90.       90.      ] >
# 0:00:22.307246
# frame = 19
# < Timestep 19 with unit cell dimensions [30.699165 30.421165 29.510633 90.       90.       90.      ] >
# 0:00:23.543613
# 0:00:23.544275

# %% [markdown]
# # Whole Molecule Level

# %%
result_wm=poseidon_object.run_analysis(level_list=['moleculeLevel'], verbose= False, forceUnits= "Kcal")
# Out:
# 2023-09-14 10:20:24.795330
#
# solvent: ['WAT', 'wat', 'SOL', 'H2O', 'h2o', 'WAT_O', 'TIP3']
#
# water: ['WAT', 'wat', 'SOL', 'H2O', 'h2o', 'WAT_O', 'TIP3']
#
# 1. Populate Dictionaries
#
# memory use: 0.22 GB
# 0:00:00.001841
# memory use: 0.22 GB
# 0:00:01.411924
# 0:00:01.412375
# memory use: 0.22 GB
#
# Total number of frames: 20.0
# Number of atoms in each frame: 916
# Number of variables in each list: 19
#
# 2. Process Dictionaries
# ['moleculeLevel']
# ---level: moleculeLevel
#
#
# 0:00:01.583820
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:859: RuntimeWarning: invalid value encountered in double_scalars
#   w = w ** 0.5
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:1515: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   solventData = pd.concat([solventData, newRowSolvent], ignore_index=True)
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:1552: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   soluteData = pd.concat([soluteData, newRowSolute], ignore_index=True)

# %%
result_wm
# Out:
# {'moleculeLevel': {'solventData':    nearest assigned  shell_num   variable      value count
#   0      ACE      WAT        1.0  Sor_test2   4.489916   155
#   1      ACE      WAT        1.0     Strans  47.114194   155
#   2      ACE      WAT        1.0       Srot  21.518819   155
#   3      ACE      WAT        1.0      count   7.750000   155
#   4      ARG      WAT        1.0  Sor_test2   4.389286   358
#   5      ARG      WAT        1.0     Strans  46.659296   358
#   6      ARG      WAT        1.0       Srot  21.813924   358
#   7      ARG      WAT        1.0      count  17.900000   358
#   8      NME      WAT        1.0  Sor_test2   2.782703   117
#   9      NME      WAT        1.0     Strans  46.479766   117
#   10     NME      WAT        1.0       Srot  20.958346   117
#   11     NME      WAT        1.0      count   5.850000   117,
#   'soluteData':    resName      variable       value count
#   0      ACE     WM_Strans   31.209380    20
#   1      ACE       WM_Srot   18.233384    20
#   2      ACE  WM_UA_Strans    1.450273    20
#   3      ACE    WM_UA_Srot   17.256750    20
#   4      ARG     WM_Strans   37.553747    20
#   5      ARG       WM_Srot   10.551190    20
#   6      ARG  WM_UA_Strans  203.095275    20
#   7      ARG    WM_UA_Srot         NaN    20
#   8      ARG       conf_AE   18.358527    20
#   9      NME     WM_Strans   28.852401    20
#   10     NME       WM_Srot    0.387749    20
#   11     NME  WM_UA_Strans    0.000000    20
#   12     NME    WM_UA_Srot   27.433272    20}}

# %%
wm_solvent_df=result_wm['moleculeLevel']['solventData']

# %%
wm_solvent_df
# Out:
#    nearest assigned  shell_num   variable      value count
# 0      ACE      WAT        1.0  Sor_test2   4.489916   155
# 1      ACE      WAT        1.0     Strans  47.114194   155
# 2      ACE      WAT        1.0       Srot  21.518819   155
# 3      ACE      WAT        1.0      count   7.750000   155
# 4      ARG      WAT        1.0  Sor_test2   4.389286   358
# 5      ARG      WAT        1.0     Strans  46.659296   358
# 6      ARG      WAT        1.0       Srot  21.813924   358
# 7      ARG      WAT        1.0      count  17.900000   358
# 8      NME      WAT        1.0  Sor_test2   2.782703   117
# 9      NME      WAT        1.0     Strans  46.479766   117
# 10     NME      WAT        1.0       Srot  20.958346   117
# 11     NME      WAT        1.0      count   5.850000   117

# %%
wm_solvent_df.to_csv('wm_solvent.csv')

# %%
wm_solute_df=result_wm['moleculeLevel']['soluteData']

# %%
wm_solute_df
# Out:
#    resName      variable       value count
# 0      ACE     WM_Strans   31.209380    20
# 1      ACE       WM_Srot   18.233384    20
# 2      ACE  WM_UA_Strans    1.450273    20
# 3      ACE    WM_UA_Srot   17.256750    20
# 4      ARG     WM_Strans   37.553747    20
# 5      ARG       WM_Srot   10.551190    20
# 6      ARG  WM_UA_Strans  203.095275    20
# 7      ARG    WM_UA_Srot         NaN    20
# 8      ARG       conf_AE   18.358527    20
# 9      NME     WM_Strans   28.852401    20
# 10     NME       WM_Srot    0.387749    20
# 11     NME  WM_UA_Strans    0.000000    20
# 12     NME    WM_UA_Srot   27.433272    20

# %%
wm_solute_df.to_csv('wm_solute.csv')

# %% [markdown]
# # Residue Level

# %%
result_res=poseidon_object.run_analysis(level_list=['residLevel_resname'], verbose=False, forceUnits='Kcal')
# Out:
# 2023-09-14 10:20:40.927585
#
# solvent: ['WAT', 'wat', 'SOL', 'H2O', 'h2o', 'WAT_O', 'TIP3']
#
# water: ['WAT', 'wat', 'SOL', 'H2O', 'h2o', 'WAT_O', 'TIP3']
#
# 1. Populate Dictionaries
#
# memory use: 0.221 GB
# 0:00:00.001499
# memory use: 0.222 GB
# 0:00:01.423385
# 0:00:01.423809
# memory use: 0.222 GB
#
# Total number of frames: 20.0
# Number of atoms in each frame: 916
# Number of variables in each list: 19
#
# 2. Process Dictionaries
# ['residLevel_resname']
# ---level: residLevel_resname
#
#
# 0:00:01.585522
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:859: RuntimeWarning: invalid value encountered in double_scalars
#   w = w ** 0.5
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:1515: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   solventData = pd.concat([solventData, newRowSolvent], ignore_index=True)
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:1552: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   soluteData = pd.concat([soluteData, newRowSolute], ignore_index=True)
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:125: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   contactMatrix = pd.concat([contactMatrix, newRowContact], ignore_index=True)

# %%
print(result_res)
# Out:
# {'residLevel_resname': {'solventData':    nearest assigned  shell_num   variable      value count
# 0    ACE_1      WAT        1.0  Sor_test2   4.489916   155
# 1    ACE_1      WAT        1.0     Strans  47.114194   155
# 2    ACE_1      WAT        1.0       Srot  21.518819   155
# 3    ACE_1      WAT        1.0      count   7.750000   155
# 4    ARG_2      WAT        1.0  Sor_test2   4.389286   358
# 5    ARG_2      WAT        1.0     Strans  46.659296   358
# 6    ARG_2      WAT        1.0       Srot  21.813924   358
# 7    ARG_2      WAT        1.0      count  17.900000   358
# 8    NME_3      WAT        1.0  Sor_test2   2.782703   117
# 9    NME_3      WAT        1.0     Strans  46.479766   117
# 10   NME_3      WAT        1.0       Srot  20.958346   117
# 11   NME_3      WAT        1.0      count   5.850000   117, 'soluteData':    resName      variable       value count
# 0    ACE_1     WM_Strans   31.209380    20
# 1    ACE_1       WM_Srot   18.233384    20
# 2    ACE_1  WM_UA_Strans    1.450273    20
# 3    ACE_1    WM_UA_Srot   17.256750    20
# 4    ARG_2     WM_Strans   37.553747    20
# 5    ARG_2       WM_Srot   10.551190    20
# 6    ARG_2  WM_UA_Strans  203.095275    20
# 7    ARG_2    WM_UA_Srot         NaN    20
# 8    ARG_2       conf_AE   18.358527    20
# 9    NME_3     WM_Strans   28.852401    20
# 10   NME_3       WM_Srot    0.387749    20
# 11   NME_3  WM_UA_Strans    0.000000    20
# 12   NME_3    WM_UA_Srot   27.433272    20, 'contactMatrix':   centre_resid neighbour_resid  count centre_resname neighbour_resname
# 0            1               2    3.0          ACE_1               ARG
# 1            1               3    0.1          ACE_1               NME
# 2            2               1    3.0          ARG_2               ACE
# 3            2               3    3.0          ARG_2               NME
# 4            3               1    0.1          NME_3               ACE
# 5            3               2    3.0          NME_3               ARG}}

# %%
res_solvent_df=result_res['residLevel_resname']['solventData']

# %%
res_solvent_df
# Out:
#    nearest assigned  shell_num   variable      value count
# 0    ACE_1      WAT        1.0  Sor_test2   4.489916   155
# 1    ACE_1      WAT        1.0     Strans  47.114194   155
# 2    ACE_1      WAT        1.0       Srot  21.518819   155
# 3    ACE_1      WAT        1.0      count   7.750000   155
# 4    ARG_2      WAT        1.0  Sor_test2   4.389286   358
# 5    ARG_2      WAT        1.0     Strans  46.659296   358
# 6    ARG_2      WAT        1.0       Srot  21.813924   358
# 7    ARG_2      WAT        1.0      count  17.900000   358
# 8    NME_3      WAT        1.0  Sor_test2   2.782703   117
# 9    NME_3      WAT        1.0     Strans  46.479766   117
# 10   NME_3      WAT        1.0       Srot  20.958346   117
# 11   NME_3      WAT        1.0      count   5.850000   117

# %%
res_solvent_df.to_csv('res_solvent.csv')

# %%
res_solute_df=result_res['residLevel_resname']['soluteData']

# %%
res_solute_df
# Out:
#    resName      variable       value count
# 0    ACE_1     WM_Strans   31.209380    20
# 1    ACE_1       WM_Srot   18.233384    20
# 2    ACE_1  WM_UA_Strans    1.450273    20
# 3    ACE_1    WM_UA_Srot   17.256750    20
# 4    ARG_2     WM_Strans   37.553747    20
# 5    ARG_2       WM_Srot   10.551190    20
# 6    ARG_2  WM_UA_Strans  203.095275    20
# 7    ARG_2    WM_UA_Srot         NaN    20
# 8    ARG_2       conf_AE   18.358527    20
# 9    NME_3     WM_Strans   28.852401    20
# 10   NME_3       WM_Srot    0.387749    20
# 11   NME_3  WM_UA_Strans    0.000000    20
# 12   NME_3    WM_UA_Srot   27.433272    20

# %%
res_solute_df.to_csv('res_solute.csv')

# %% [markdown]
# # United Atom Level

# %%
result_ua= poseidon_object.run_analysis(level_list=['atomLevel'], verbose=False, forceUnits="Kcal")
# Out:
# 2023-09-14 10:20:50.355536
#
# solvent: ['WAT', 'wat', 'SOL', 'H2O', 'h2o', 'WAT_O', 'TIP3']
#
# water: ['WAT', 'wat', 'SOL', 'H2O', 'h2o', 'WAT_O', 'TIP3']
#
# 1. Populate Dictionaries
#
# memory use: 0.222 GB
# 0:00:00.001044
# memory use: 0.222 GB
# 0:00:01.473437
# 0:00:01.473906
# memory use: 0.222 GB
#
# Total number of frames: 20.0
# Number of atoms in each frame: 916
# Number of variables in each list: 19
#
# 2. Process Dictionaries
# ['atomLevel']
# ---level: atomLevel
#
#
# 0:00:01.674288
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:859: RuntimeWarning: invalid value encountered in double_scalars
#   w = w ** 0.5
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:1515: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   solventData = pd.concat([solventData, newRowSolvent], ignore_index=True)
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:1552: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   soluteData = pd.concat([soluteData, newRowSolute], ignore_index=True)
# /home/ioana/Desktop/STFC/CodeEntropy/code/CodeEntropy/CodeEntropy/poseidon/analysis/EECalculation.py:109: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   contactMatrix = pd.concat([contactMatrix, newRowContact], ignore_index=True)

# %%
print(result_ua)
# Out:
# {'atomLevel': {'solventData':    nearest assigned  shell_num   variable      value count
# 0    ACE_C    WAT_O        1.0  Sor_test2   3.859492    90
# 1    ACE_C    WAT_O        1.0     Strans  46.896420    90
# 2    ACE_C    WAT_O        1.0       Srot  21.477797    90
# 3    ACE_C    WAT_O        1.0      count   4.500000    90
# 4    ACE_O    WAT_O        1.0  Sor_test2   1.383652    65
# 5    ACE_O    WAT_O        1.0     Strans  47.442017    65
# 6    ACE_O    WAT_O        1.0       Srot  21.607751    65
# 7    ACE_O    WAT_O        1.0      count   3.250000    65
# 8    ARG_C    WAT_O        1.0  Sor_test2   2.209787    94
# 9    ARG_C    WAT_O        1.0     Strans  44.950488    94
# 10   ARG_C    WAT_O        1.0       Srot  22.805753    94
# 11   ARG_C    WAT_O        1.0      count   4.700000    94
# 12   ARG_N    WAT_O        1.0  Sor_test2   4.322510   213
# 13   ARG_N    WAT_O        1.0     Strans  47.054251   213
# 14   ARG_N    WAT_O        1.0       Srot  21.210664   213
# 15   ARG_N    WAT_O        1.0      count  10.650000   213
# 16   ARG_O    WAT_O        1.0  Sor_test2   0.658554    51
# 17   ARG_O    WAT_O        1.0     Strans  49.519626    51
# 18   ARG_O    WAT_O        1.0       Srot  23.221778    51
# 19   ARG_O    WAT_O        1.0      count   2.550000    51
# 20   NME_C    WAT_O        1.0  Sor_test2   2.876769    92
# 21   NME_C    WAT_O        1.0     Strans  46.592128    92
# 22   NME_C    WAT_O        1.0       Srot  20.791071    92
# 23   NME_C    WAT_O        1.0      count   4.600000    92
# 24   NME_N    WAT_O        1.0  Sor_test2   0.360700    25
# 25   NME_N    WAT_O        1.0     Strans  46.337027    25
# 26   NME_N    WAT_O        1.0       Srot  21.698027    25
# 27   NME_N    WAT_O        1.0      count   1.250000    25, 'soluteData':    resName      variable       value count
# 0    ACE_C     WM_Strans   31.209380    20
# 1    ACE_C       WM_Srot   18.233384    20
# 2    ACE_C  WM_UA_Strans    1.450273    20
# 3    ACE_C    WM_UA_Srot   17.256750    20
# 4    ARG_N     WM_Strans   37.553747    20
# 5    ARG_N       WM_Srot   10.551190    20
# 6    ARG_N  WM_UA_Strans  203.095275    20
# 7    ARG_N    WM_UA_Srot         NaN    20
# 8    ARG_N       conf_AE   18.358527    20
# 9    NME_N     WM_Strans   28.852401    20
# 10   NME_N       WM_Srot    0.387749    20
# 11   NME_N  WM_UA_Strans    0.000000    20
# 12   NME_N    WM_UA_Srot   27.433272    20, 'contactMatrix':    centre_resid neighbour_resid  count centre_resname neighbour_resname  \
# 0             1               2    1.0            ACE               ARG
# 1             2               3    1.0            ARG               NME
# 2             2               1    1.0            ARG               ACE
# 3             2               3    1.0            ARG               NME
# 4             1               2    1.0            ACE               ARG
# 5             3               2    1.0            NME               ARG
# 6             2               1    1.0            ARG               ACE
# 7             2               1    1.0            ARG               ACE
# 8             3               2    1.0            NME               ARG
# 9             3               1    0.1            NME               ACE
# 10            3               2    1.0            NME               ARG
# 11            1               2    1.0            ACE               ARG
# 12            1               3    0.1            ACE               NME
# 13            2               3    1.0            ARG               NME
#
#    centre_atom neighbour_atom
# 0            C             CA
# 1            C            CH3
# 2           CA              C
# 3           CA              N
# 4          CH3              N
# 5          CH3              C
# 6            N            CH3
# 7            N              O
# 8            N             CA
# 9            N              O
# 10           N              O
# 11           O              N
# 12           O              N
# 13           O              N  }}

# %%
ua_solvent_df=result_ua['atomLevel']['solventData']

# %%
ua_solvent_df
# Out:
#    nearest assigned  shell_num   variable      value count
# 0    ACE_C    WAT_O        1.0  Sor_test2   3.859492    90
# 1    ACE_C    WAT_O        1.0     Strans  46.896420    90
# 2    ACE_C    WAT_O        1.0       Srot  21.477797    90
# 3    ACE_C    WAT_O        1.0      count   4.500000    90
# 4    ACE_O    WAT_O        1.0  Sor_test2   1.383652    65
# 5    ACE_O    WAT_O        1.0     Strans  47.442017    65
# 6    ACE_O    WAT_O        1.0       Srot  21.607751    65
# 7    ACE_O    WAT_O        1.0      count   3.250000    65
# 8    ARG_C    WAT_O        1.0  Sor_test2   2.209787    94
# 9    ARG_C    WAT_O        1.0     Strans  44.950488    94
# 10   ARG_C    WAT_O        1.0       Srot  22.805753    94
# 11   ARG_C    WAT_O        1.0      count   4.700000    94
# 12   ARG_N    WAT_O        1.0  Sor_test2   4.322510   213
# 13   ARG_N    WAT_O        1.0     Strans  47.054251   213
# 14   ARG_N    WAT_O        1.0       Srot  21.210664   213
# 15   ARG_N    WAT_O        1.0      count  10.650000   213
# 16   ARG_O    WAT_O        1.0  Sor_test2   0.658554    51
# 17   ARG_O    WAT_O        1.0     Strans  49.519626    51
# 18   ARG_O    WAT_O        1.0       Srot  23.221778    51
# 19   ARG_O    WAT_O        1.0      count   2.550000    51
# 20   NME_C    WAT_O        1.0  Sor_test2   2.876769    92
# 21   NME_C    WAT_O        1.0     Strans  46.592128    92
# 22   NME_C    WAT_O        1.0       Srot  20.791071    92
# 23   NME_C    WAT_O        1.0      count   4.600000    92
# 24   NME_N    WAT_O        1.0  Sor_test2   0.360700    25
# 25   NME_N    WAT_O        1.0     Strans  46.337027    25
# 26   NME_N    WAT_O        1.0       Srot  21.698027    25
# 27   NME_N    WAT_O        1.0      count   1.250000    25

# %%
ua_solvent_df.to_csv('ua_solvent.csv')

# %%
ua_solute_df=result_ua['atomLevel']['soluteData']

# %%
ua_solute_df
# Out:
#    resName      variable       value count
# 0    ACE_C     WM_Strans   31.209380    20
# 1    ACE_C       WM_Srot   18.233384    20
# 2    ACE_C  WM_UA_Strans    1.450273    20
# 3    ACE_C    WM_UA_Srot   17.256750    20
# 4    ARG_N     WM_Strans   37.553747    20
# 5    ARG_N       WM_Srot   10.551190    20
# 6    ARG_N  WM_UA_Strans  203.095275    20
# 7    ARG_N    WM_UA_Srot         NaN    20
# 8    ARG_N       conf_AE   18.358527    20
# 9    NME_N     WM_Strans   28.852401    20
# 10   NME_N       WM_Srot    0.387749    20
# 11   NME_N  WM_UA_Strans    0.000000    20
# 12   NME_N    WM_UA_Srot   27.433272    20

# %%
ua_solute_df.to_csv('ua_solute.csv')

# %%
result_solcon = poseidon_object.run_analysis (level_list = ['soluteContacts'], verbose = 'False', forceUnits="Kcal")
# Out:
# 2023-09-14 10:21:04.199436
#
# solvent: ['WAT', 'wat', 'SOL', 'H2O', 'h2o', 'WAT_O', 'TIP3']
#
# water: ['WAT', 'wat', 'SOL', 'H2O', 'h2o', 'WAT_O', 'TIP3']
#
# 1. Populate Dictionaries
#
# memory use: 0.222 GB
# 0:00:00.001203
# memory use: 0.222 GB
# 0:00:00.092006
# 0:00:00.092649
# memory use: 0.222 GB
#
# Total number of frames: 20.0
# Number of atoms in each frame: 916
# Number of variables in each list: 19
#
# 2. Process Dictionaries
# ['soluteContacts']
# ---level: soluteContacts
#
#
# ---ANALYSIS_TYPE_EE---
#
#
#
# ---ORIENTATIONAL_ENTROPY_CALCULATIONS---
#
#
#
# __ORIENTATIONAL_ENTROPY_Sor_test2
#
# all molecule count: 580
#
#
# nearest: ACE_1_ACE_1 count: 38 / 580
# 	assigned: ('WAT', 2, 'O') count: 38 / 38
# 	N_H 2
# 			shell_num: 0 count: 19 / 38
# 				 -----RADshell------
# 				neighbours: 0,1,1,1,2,2,2,ACE_CH3 Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 ACE_CH3 1
# 					 sum i counts: 3
# 						 pi 1 0.1111 degen: 3 pi_d: 0.3333
# 						 pi 2 0.1111 degen: 3 pi_d: 0.3333
# 						 pi ACE_CH3 0.3333 degen: 1 pi_d: 0.3333
# 					 --ij--
# 					 ('1', '2', 'ACE_CH3') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2', 'ACE_CH3') 0.1111 degen: 9 pij_d: 1.0
# 						 pij_max 0.11111
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.333
# 						 largest_pij 1.0
# 						 largest_pi 0.333
# 					 __D__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 1 0.1667 degen: 3 pi_d: 0.5
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('1', '2') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2') 0.1111 degen: 9 pij_d: 1.0
# 						 pij_max 0.11111
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 3 pA_count 1 pD_count 1
# 						 i 1 N_i 3 ppA_i 0.4 ppD_i 0.6 N_i_eff 2.88 pbias_i 0.24
# 					 i 2 N_i 3 pA_count 1 pD_count 1
# 						 i 2 N_i 3 ppA_i 0.4 ppD_i 0.6 N_i_eff 2.88 pbias_i 0.24
# 					 i ACE_CH3 N_i 1 pA_count 1 pD_count 0
# 					 Nc_eff 5.76
# 					 pbias_ave 0.18
# 					 S3 (test2) 0.79083
# 				S7_DA =  0.791
#
# 				 *** Sor-list:
# 				 0.791 DA <-- selected Sor
# 				S6 =  0.042
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,2,2,ACE_CH3 Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 1
# 					 ACE_CH3 1
# 					 sum i counts: 2
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 						 pi ACE_CH3 0.5 degen: 1 pi_d: 0.5
# 					 --ij--
# 					 ('1', 'ACE_CH3') 1
# 					 sum pair counts: 1
# 						 pij ('1', 'ACE_CH3') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.25 degen: 4 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 0.1667 degen: 6 pij_d: 1.0
# 						 pij_max 0.16667
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 1 pD_count 0
# 					 i 2 N_i 4 pA_count 0 pD_count 2
# 					 i ACE_CH3 N_i 1 pA_count 1 pD_count 0
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,2,ACE_C,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 1 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 						 pi X 0.5 degen: 1 pi_d: 0.5
# 					 --ij--
# 					 ('1', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('1', 'X') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 0 pD_count 1
# 					 i 2 N_i 3 pA_count 2 pD_count 0
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 0 pD_count 1
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,2,ACE_C,X,X Nc: 9 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 1 1
# 					 X 1
# 					 sum i counts: 3
# 						 pi 0 0.3333 degen: 1 pi_d: 0.3333
# 						 pi 1 0.1667 degen: 2 pi_d: 0.3333
# 						 pi X 0.1667 degen: 2 pi_d: 0.3333
# 					 --ij--
# 					 ('0', '1', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('0', '1', 'X') 0.25 degen: 4 pij_d: 1.0
# 						 pij_max 0.25
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 9 7
# 						 solute_pijs 1.0
# 						 solute_pis 0.333
# 						 largest_pij 1.0
# 						 largest_pi 0.333
# 					 __D__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 9 7
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 2 pA_count 1 pD_count 0
# 					 i 2 N_i 3 pA_count 0 pD_count 2
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 2 pA_count 1 pD_count 0
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,ACE_CH3,ACE_O,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 2
# 					 sum i counts: 2
# 						 pi 1 0.5 degen: 2 pi_d: 1.0
# 					 --ij--
# 					 ('1', '1') 1
# 					 sum pair counts: 1
# 						 pij ('1', '1') 1.0 degen: 1 pij_d: 1.0
# 						 pij_max 1.0
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.5 degen: 2 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 1.0 degen: 1 pij_d: 1.0
# 						 pij_max 1.0
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 2 pD_count 0
# 					 i 2 N_i 2 pA_count 0 pD_count 2
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i ACE_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 0 pD_count 0
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,ACE_O,X Nc: 7 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 						 pi X 0.5 degen: 1 pi_d: 0.5
# 					 --ij--
# 					 ('1', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('1', 'X') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 						 pi 2 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('1', '2') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2') 0.25 degen: 4 pij_d: 1.0
# 						 pij_max 0.25
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 1 pD_count 1
# 						 i 1 N_i 2 ppA_i 0.5 ppD_i 0.5 N_i_eff 2.0 pbias_i 0.25
# 					 i 2 N_i 2 pA_count 0 pD_count 1
# 					 i ACE_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 1 pD_count 0
# 					 Nc_eff 2.0
# 					 pbias_ave 0.07143
# 					 S3 (test2) -1.72012
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,ACE_C,ACE_CH3,NME_CH3,X,X,X Nc: 10 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 1 1
# 					 sum i counts: 2
# 						 pi 0 0.5 degen: 1 pi_d: 0.5
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('0', '1') 1
# 					 sum pair counts: 1
# 						 pij ('0', '1') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 10 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 X 2
# 					 sum i counts: 2
# 						 pi X 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('X', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('X', 'X') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 10 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 2 pA_count 1 pD_count 0
# 					 i 2 N_i 1 pA_count 0 pD_count 0
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i NME_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 3 pA_count 0 pD_count 2
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,ACE_C,NME_N,X,X Nc: 7 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 NME_N 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi NME_N 0.5 degen: 1 pi_d: 0.5
# 						 pi X 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('NME_N', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('NME_N', 'X') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 7 4
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 1 2
# 					 sum i counts: 2
# 						 pi 1 0.5 degen: 2 pi_d: 1.0
# 					 --ij--
# 					 ('1', '1') 1
# 					 sum pair counts: 1
# 						 pij ('1', '1') 1.0 degen: 1 pij_d: 1.0
# 						 pij_max 1.0
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 4
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 0 pD_count 2
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i NME_N N_i 1 pA_count 1 pD_count 0
# 					 i X N_i 2 pA_count 1 pD_count 0
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,2,2,ACE_CH3 Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.2 degen: 5 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 0.1 degen: 10 pij_d: 1.0
# 						 pij_max 0.1
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 0 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 0 0.5 degen: 1 pi_d: 0.5
# 						 pi 2 0.1 degen: 5 pi_d: 0.5
# 					 --ij--
# 					 ('0', '2') 1
# 					 sum pair counts: 1
# 						 pij ('0', '2') 0.2 degen: 5 pij_d: 1.0
# 						 pij_max 0.2
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 1
# 					 i 1 N_i 1 pA_count 0 pD_count 0
# 					 i 2 N_i 5 pA_count 2 pD_count 1
# 						 i 2 N_i 5 ppA_i 0.66667 ppD_i 0.33333 N_i_eff 4.44444 pbias_i 0.22222
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 Nc_eff 4.44444
# 					 pbias_ave 0.13889
# 					 S3 (test2) 0.14262
# 				S7_DA =  0.143
#
# 				 *** Sor-list:
# 				 0.143 DA <-- selected Sor
# 				S6 =  0.008
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,2,ACE_CH3,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 3
# 					 X 1
# 					 sum i counts: 4
# 						 pi 2 0.1875 degen: 4 pi_d: 0.75
# 						 pi X 0.25 degen: 1 pi_d: 0.25
# 					 --ij--
# 					 ('2', '2', '2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2', '2', 'X') 0.25 degen: 4 pij_d: 1.0
# 						 pij_max 0.25
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.75
# 					 __D__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 1 0.5 degen: 1 pi_d: 0.5
# 						 pi 2 0.125 degen: 4 pi_d: 0.5
# 					 --ij--
# 					 ('1', '2') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2') 0.25 degen: 4 pij_d: 1.0
# 						 pij_max 0.25
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 1
# 					 i 2 N_i 4 pA_count 3 pD_count 1
# 						 i 2 N_i 4 ppA_i 0.6 ppD_i 0.4 N_i_eff 3.84 pbias_i 0.24
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 1 pD_count 0
# 					 Nc_eff 3.84
# 					 pbias_ave 0.12
# 					 S3 (test2) -0.22284
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,ACE_C,X Nc: 7 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 1
# 					 sum i counts: 1
# 						 pi 2 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('2',) 1
# 					 sum pair counts: 1
# 						 pij ('2',) 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 1 0.5 degen: 1 pi_d: 0.5
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('1', '2') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 1
# 					 i 2 N_i 3 pA_count 1 pD_count 1
# 						 i 2 N_i 3 ppA_i 0.66667 ppD_i 0.33333 N_i_eff 2.66667 pbias_i 0.22222
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 0 pD_count 0
# 					 Nc_eff 2.66667
# 					 pbias_ave 0.09524
# 					 S3 (test2) -1.00091
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,ACE_O,X,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 1
# 					 sum i counts: 1
# 						 pi 2 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('2',) 1
# 					 sum pair counts: 1
# 						 pij ('2',) 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 2 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 						 pi X 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', 'X') 0.1667 degen: 6 pij_d: 1.0
# 						 pij_max 0.16667
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 0
# 					 i 2 N_i 3 pA_count 1 pD_count 1
# 						 i 2 N_i 3 ppA_i 0.66667 ppD_i 0.33333 N_i_eff 2.66667 pbias_i 0.22222
# 					 i ACE_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 2 pA_count 0 pD_count 1
# 					 Nc_eff 2.66667
# 					 pbias_ave 0.08333
# 					 S3 (test2) -1.13445
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,ACE_O,X,X,X Nc: 9 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 						 pi X 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', 'X') 0.1111 degen: 9 pij_d: 1.0
# 						 pij_max 0.11111
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 9 7
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 2 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 						 pi X 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', 'X') 0.1111 degen: 9 pij_d: 1.0
# 						 pij_max 0.11111
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 9 7
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 0
# 					 i 2 N_i 3 pA_count 1 pD_count 1
# 						 i 2 N_i 3 ppA_i 0.5 ppD_i 0.5 N_i_eff 3.0 pbias_i 0.25
# 					 i ACE_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 3 pA_count 1 pD_count 1
# 						 i X N_i 3 ppA_i 0.5 ppD_i 0.5 N_i_eff 3.0 pbias_i 0.25
# 					 Nc_eff 6.0
# 					 pbias_ave 0.16667
# 					 S3 (test2) 0.7751
# 				S7_DA =  0.775
#
# 				 *** Sor-list:
# 				 0.775 DA <-- selected Sor
# 				S6 =  0.041
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,ACE_C,ACE_CH3,X,X,X Nc: 8 count: 2 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 1 1
# 					 ACE_CH3 1
# 					 X 2
# 					 sum i counts: 5
# 						 pi 0 0.2 degen: 1 pi_d: 0.2
# 						 pi 1 0.2 degen: 1 pi_d: 0.2
# 						 pi ACE_CH3 0.2 degen: 1 pi_d: 0.2
# 						 pi X 0.1333 degen: 3 pi_d: 0.4
# 					 --ij--
# 					 ('0', '1', 'ACE_CH3') 1
# 					 ('X', 'X') 1
# 					 sum pair counts: 2
# 						 pij ('0', '1', 'ACE_CH3') 0.5 degen: 1 pij_d: 0.5
# 						 pij ('X', 'X') 0.1667 degen: 3 pij_d: 0.5
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0.5
# 						 solute_pis 0.4
# 						 largest_pij 0.5
# 						 largest_pi 0.4
# 					 __D__
# 					 --i--
# 					 2 1
# 					 X 2
# 					 1 1
# 					 sum i counts: 4
# 						 pi 2 0.25 degen: 1 pi_d: 0.25
# 						 pi X 0.1667 degen: 3 pi_d: 0.5
# 						 pi 1 0.25 degen: 1 pi_d: 0.25
# 					 --ij--
# 					 ('2', 'X') 1
# 					 ('1', 'X') 1
# 					 sum pair counts: 2
# 						 pij ('2', 'X') 0.1667 degen: 3 pij_d: 0.5
# 						 pij ('1', 'X') 0.1667 degen: 3 pij_d: 0.5
# 						 pij_max 0.16667
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 0.5
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 1 pA_count 1 pD_count 1
# 						 i 1 N_i 1 ppA_i 0.44444 ppD_i 0.55556 N_i_eff 0.98765 pbias_i 0.24691
# 					 i 2 N_i 1 pA_count 0 pD_count 1
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i ACE_CH3 N_i 1 pA_count 1 pD_count 0
# 					 i X N_i 3 pA_count 2 pD_count 2
# 						 i X N_i 3 ppA_i 0.44444 ppD_i 0.55556 N_i_eff 2.96296 pbias_i 0.24691
# 					 Nc_eff 3.95062
# 					 pbias_ave 0.12346
# 					 S3 (test2) -0.15184
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,ACE_C,ARG_CB,X,X,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 X 2
# 					 sum i counts: 3
# 						 pi 0 0.3333 degen: 1 pi_d: 0.3333
# 						 pi X 0.2222 degen: 3 pi_d: 0.6667
# 					 --ij--
# 					 ('0', 'X', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('0', 'X', 'X') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 1.0
# 						 solute_pis 0.333
# 						 largest_pij 1.0
# 						 largest_pi 0.667
# 					 __D__
# 					 --i--
# 					 2 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 2 0.5 degen: 1 pi_d: 0.5
# 						 pi X 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', 'X') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 0
# 					 i 2 N_i 1 pA_count 0 pD_count 1
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i ARG_CB N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 3 pA_count 2 pD_count 1
# 						 i X N_i 3 ppA_i 0.57143 ppD_i 0.42857 N_i_eff 2.93878 pbias_i 0.2449
# 					 Nc_eff 2.93878
# 					 pbias_ave 0.09184
# 					 S3 (test2) -0.89154
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,ACE_C,ACE_CH3,ARG_N,X,X,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 1 1
# 					 ARG_N 1
# 					 sum i counts: 3
# 						 pi 0 0.3333 degen: 1 pi_d: 0.3333
# 						 pi 1 0.3333 degen: 1 pi_d: 0.3333
# 						 pi ARG_N 0.3333 degen: 1 pi_d: 0.3333
# 					 --ij--
# 					 ('0', '1', 'ARG_N') 1
# 					 sum pair counts: 1
# 						 pij ('0', '1', 'ARG_N') 1.0 degen: 1 pij_d: 1.0
# 						 pij_max 1.0
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 4
# 						 solute_pijs 1.0
# 						 solute_pis 0.667
# 						 largest_pij 1.0
# 						 largest_pi 0.333
# 					 __D__
# 					 --i--
# 					 X 2
# 					 sum i counts: 2
# 						 pi X 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('X', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('X', 'X') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 4
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 1 pA_count 1 pD_count 0
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i ARG_N N_i 1 pA_count 1 pD_count 0
# 					 i X N_i 3 pA_count 0 pD_count 2
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,2,2,2,ACE_CH3,X Nc: 6 count: 2 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 2
# 					 ACE_CH3 1
# 					 sum i counts: 3
# 						 pi 2 0.2222 degen: 3 pi_d: 0.6667
# 						 pi ACE_CH3 0.3333 degen: 1 pi_d: 0.3333
# 					 --ij--
# 					 ('2', '2', 'ACE_CH3') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2', 'ACE_CH3') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 6 4
# 						 solute_pijs 1.0
# 						 solute_pis 0.333
# 						 largest_pij 1.0
# 						 largest_pi 0.667
# 					 __D__
# 					 --i--
# 					 2 2
# 					 X 1
# 					 0 1
# 					 sum i counts: 4
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 						 pi X 0.25 degen: 1 pi_d: 0.25
# 						 pi 0 0.25 degen: 1 pi_d: 0.25
# 					 --ij--
# 					 ('2', 'X') 1
# 					 ('0', '2') 1
# 					 sum pair counts: 2
# 						 pij ('2', 'X') 0.1667 degen: 3 pij_d: 0.5
# 						 pij ('0', '2') 0.1667 degen: 3 pij_d: 0.5
# 						 pij_max 0.16667
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 6 4
# 						 solute_pijs 0.5
# 						 solute_pis 0.25
# 						 largest_pij 0.5
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 1
# 					 i 2 N_i 3 pA_count 2 pD_count 2
# 						 i 2 N_i 3 ppA_i 0.57143 ppD_i 0.42857 N_i_eff 2.93878 pbias_i 0.2449
# 					 i ACE_CH3 N_i 1 pA_count 1 pD_count 0
# 					 i X N_i 1 pA_count 0 pD_count 1
# 					 Nc_eff 2.93878
# 					 pbias_ave 0.12245
# 					 S3 (test2) -0.60385
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 			S5 =  0.045
# 			shell_num: 1 count: 19 / 38
# 				 -----RADshell------
# 				neighbours: 0,1,1,1,2,2,2,ACE_CH3 Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 ACE_CH3 1
# 					 sum i counts: 3
# 						 pi 1 0.1111 degen: 3 pi_d: 0.3333
# 						 pi 2 0.1111 degen: 3 pi_d: 0.3333
# 						 pi ACE_CH3 0.3333 degen: 1 pi_d: 0.3333
# 					 --ij--
# 					 ('1', '2', 'ACE_CH3') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2', 'ACE_CH3') 0.1111 degen: 9 pij_d: 1.0
# 						 pij_max 0.11111
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.333
# 						 largest_pij 1.0
# 						 largest_pi 0.333
# 					 __D__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 1 0.1667 degen: 3 pi_d: 0.5
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('1', '2') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2') 0.1111 degen: 9 pij_d: 1.0
# 						 pij_max 0.11111
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 3 pA_count 1 pD_count 1
# 						 i 1 N_i 3 ppA_i 0.4 ppD_i 0.6 N_i_eff 2.88 pbias_i 0.24
# 					 i 2 N_i 3 pA_count 1 pD_count 1
# 						 i 2 N_i 3 ppA_i 0.4 ppD_i 0.6 N_i_eff 2.88 pbias_i 0.24
# 					 i ACE_CH3 N_i 1 pA_count 1 pD_count 0
# 					 Nc_eff 5.76
# 					 pbias_ave 0.18
# 					 S3 (test2) 0.79083
# 				S7_DA =  0.791
#
# 				 *** Sor-list:
# 				 0.791 DA <-- selected Sor
# 				S6 =  0.042
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,2,2,ACE_CH3 Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 1
# 					 ACE_CH3 1
# 					 sum i counts: 2
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 						 pi ACE_CH3 0.5 degen: 1 pi_d: 0.5
# 					 --ij--
# 					 ('1', 'ACE_CH3') 1
# 					 sum pair counts: 1
# 						 pij ('1', 'ACE_CH3') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.25 degen: 4 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 0.1667 degen: 6 pij_d: 1.0
# 						 pij_max 0.16667
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 1 pD_count 0
# 					 i 2 N_i 4 pA_count 0 pD_count 2
# 					 i ACE_CH3 N_i 1 pA_count 1 pD_count 0
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,2,ACE_C,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 1 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 						 pi X 0.5 degen: 1 pi_d: 0.5
# 					 --ij--
# 					 ('1', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('1', 'X') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 0 pD_count 1
# 					 i 2 N_i 3 pA_count 2 pD_count 0
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 0 pD_count 1
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,2,ACE_C,X,X Nc: 9 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 1 1
# 					 X 1
# 					 sum i counts: 3
# 						 pi 0 0.3333 degen: 1 pi_d: 0.3333
# 						 pi 1 0.1667 degen: 2 pi_d: 0.3333
# 						 pi X 0.1667 degen: 2 pi_d: 0.3333
# 					 --ij--
# 					 ('0', '1', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('0', '1', 'X') 0.25 degen: 4 pij_d: 1.0
# 						 pij_max 0.25
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 9 7
# 						 solute_pijs 1.0
# 						 solute_pis 0.333
# 						 largest_pij 1.0
# 						 largest_pi 0.333
# 					 __D__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 9 7
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 2 pA_count 1 pD_count 0
# 					 i 2 N_i 3 pA_count 0 pD_count 2
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 2 pA_count 1 pD_count 0
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,ACE_CH3,ACE_O,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 2
# 					 sum i counts: 2
# 						 pi 1 0.5 degen: 2 pi_d: 1.0
# 					 --ij--
# 					 ('1', '1') 1
# 					 sum pair counts: 1
# 						 pij ('1', '1') 1.0 degen: 1 pij_d: 1.0
# 						 pij_max 1.0
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.5 degen: 2 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 1.0 degen: 1 pij_d: 1.0
# 						 pij_max 1.0
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 2 pD_count 0
# 					 i 2 N_i 2 pA_count 0 pD_count 2
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i ACE_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 0 pD_count 0
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,ACE_O,X Nc: 7 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 						 pi X 0.5 degen: 1 pi_d: 0.5
# 					 --ij--
# 					 ('1', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('1', 'X') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 						 pi 2 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('1', '2') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2') 0.25 degen: 4 pij_d: 1.0
# 						 pij_max 0.25
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 1 pD_count 1
# 						 i 1 N_i 2 ppA_i 0.5 ppD_i 0.5 N_i_eff 2.0 pbias_i 0.25
# 					 i 2 N_i 2 pA_count 0 pD_count 1
# 					 i ACE_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 1 pD_count 0
# 					 Nc_eff 2.0
# 					 pbias_ave 0.07143
# 					 S3 (test2) -1.72012
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,ACE_C,ACE_CH3,NME_CH3,X,X,X Nc: 10 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 1 1
# 					 sum i counts: 2
# 						 pi 0 0.5 degen: 1 pi_d: 0.5
# 						 pi 1 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('0', '1') 1
# 					 sum pair counts: 1
# 						 pij ('0', '1') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 10 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 X 2
# 					 sum i counts: 2
# 						 pi X 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('X', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('X', 'X') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 10 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 2 pA_count 1 pD_count 0
# 					 i 2 N_i 1 pA_count 0 pD_count 0
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i NME_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 3 pA_count 0 pD_count 2
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,ACE_C,NME_N,X,X Nc: 7 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 NME_N 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi NME_N 0.5 degen: 1 pi_d: 0.5
# 						 pi X 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('NME_N', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('NME_N', 'X') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 7 4
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 1 2
# 					 sum i counts: 2
# 						 pi 1 0.5 degen: 2 pi_d: 1.0
# 					 --ij--
# 					 ('1', '1') 1
# 					 sum pair counts: 1
# 						 pij ('1', '1') 1.0 degen: 1 pij_d: 1.0
# 						 pij_max 1.0
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 4
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 2 pA_count 0 pD_count 2
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i NME_N N_i 1 pA_count 1 pD_count 0
# 					 i X N_i 2 pA_count 1 pD_count 0
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,2,2,ACE_CH3 Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 2
# 					 sum i counts: 2
# 						 pi 2 0.2 degen: 5 pi_d: 1.0
# 					 --ij--
# 					 ('2', '2') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2') 0.1 degen: 10 pij_d: 1.0
# 						 pij_max 0.1
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 0 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 0 0.5 degen: 1 pi_d: 0.5
# 						 pi 2 0.1 degen: 5 pi_d: 0.5
# 					 --ij--
# 					 ('0', '2') 1
# 					 sum pair counts: 1
# 						 pij ('0', '2') 0.2 degen: 5 pij_d: 1.0
# 						 pij_max 0.2
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 1
# 					 i 1 N_i 1 pA_count 0 pD_count 0
# 					 i 2 N_i 5 pA_count 2 pD_count 1
# 						 i 2 N_i 5 ppA_i 0.66667 ppD_i 0.33333 N_i_eff 4.44444 pbias_i 0.22222
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 Nc_eff 4.44444
# 					 pbias_ave 0.13889
# 					 S3 (test2) 0.14262
# 				S7_DA =  0.143
#
# 				 *** Sor-list:
# 				 0.143 DA <-- selected Sor
# 				S6 =  0.008
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,2,ACE_CH3,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 3
# 					 X 1
# 					 sum i counts: 4
# 						 pi 2 0.1875 degen: 4 pi_d: 0.75
# 						 pi X 0.25 degen: 1 pi_d: 0.25
# 					 --ij--
# 					 ('2', '2', '2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2', '2', 'X') 0.25 degen: 4 pij_d: 1.0
# 						 pij_max 0.25
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.75
# 					 __D__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 1 0.5 degen: 1 pi_d: 0.5
# 						 pi 2 0.125 degen: 4 pi_d: 0.5
# 					 --ij--
# 					 ('1', '2') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2') 0.25 degen: 4 pij_d: 1.0
# 						 pij_max 0.25
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 1
# 					 i 2 N_i 4 pA_count 3 pD_count 1
# 						 i 2 N_i 4 ppA_i 0.6 ppD_i 0.4 N_i_eff 3.84 pbias_i 0.24
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 1 pD_count 0
# 					 Nc_eff 3.84
# 					 pbias_ave 0.12
# 					 S3 (test2) -0.22284
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,ACE_C,X Nc: 7 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 1
# 					 sum i counts: 1
# 						 pi 2 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('2',) 1
# 					 sum pair counts: 1
# 						 pij ('2',) 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 1 1
# 					 2 1
# 					 sum i counts: 2
# 						 pi 1 0.5 degen: 1 pi_d: 0.5
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('1', '2') 1
# 					 sum pair counts: 1
# 						 pij ('1', '2') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 7 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 1
# 					 i 2 N_i 3 pA_count 1 pD_count 1
# 						 i 2 N_i 3 ppA_i 0.66667 ppD_i 0.33333 N_i_eff 2.66667 pbias_i 0.22222
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 1 pA_count 0 pD_count 0
# 					 Nc_eff 2.66667
# 					 pbias_ave 0.09524
# 					 S3 (test2) -1.00091
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,ACE_O,X,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 1
# 					 sum i counts: 1
# 						 pi 2 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('2',) 1
# 					 sum pair counts: 1
# 						 pij ('2',) 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 __D__
# 					 --i--
# 					 2 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 						 pi X 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', 'X') 0.1667 degen: 6 pij_d: 1.0
# 						 pij_max 0.16667
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 0
# 					 i 2 N_i 3 pA_count 1 pD_count 1
# 						 i 2 N_i 3 ppA_i 0.66667 ppD_i 0.33333 N_i_eff 2.66667 pbias_i 0.22222
# 					 i ACE_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 2 pA_count 0 pD_count 1
# 					 Nc_eff 2.66667
# 					 pbias_ave 0.08333
# 					 S3 (test2) -1.13445
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,2,2,ACE_O,X,X,X Nc: 9 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 						 pi X 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', 'X') 0.1111 degen: 9 pij_d: 1.0
# 						 pij_max 0.11111
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 9 7
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 __D__
# 					 --i--
# 					 2 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 						 pi X 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', 'X') 0.1111 degen: 9 pij_d: 1.0
# 						 pij_max 0.11111
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 9 7
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 0
# 					 i 2 N_i 3 pA_count 1 pD_count 1
# 						 i 2 N_i 3 ppA_i 0.5 ppD_i 0.5 N_i_eff 3.0 pbias_i 0.25
# 					 i ACE_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 3 pA_count 1 pD_count 1
# 						 i X N_i 3 ppA_i 0.5 ppD_i 0.5 N_i_eff 3.0 pbias_i 0.25
# 					 Nc_eff 6.0
# 					 pbias_ave 0.16667
# 					 S3 (test2) 0.7751
# 				S7_DA =  0.775
#
# 				 *** Sor-list:
# 				 0.775 DA <-- selected Sor
# 				S6 =  0.041
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,ACE_C,ACE_CH3,X,X,X Nc: 8 count: 2 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 1 1
# 					 ACE_CH3 1
# 					 X 2
# 					 sum i counts: 5
# 						 pi 0 0.2 degen: 1 pi_d: 0.2
# 						 pi 1 0.2 degen: 1 pi_d: 0.2
# 						 pi ACE_CH3 0.2 degen: 1 pi_d: 0.2
# 						 pi X 0.1333 degen: 3 pi_d: 0.4
# 					 --ij--
# 					 ('0', '1', 'ACE_CH3') 1
# 					 ('X', 'X') 1
# 					 sum pair counts: 2
# 						 pij ('0', '1', 'ACE_CH3') 0.5 degen: 1 pij_d: 0.5
# 						 pij ('X', 'X') 0.1667 degen: 3 pij_d: 0.5
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0.5
# 						 solute_pis 0.4
# 						 largest_pij 0.5
# 						 largest_pi 0.4
# 					 __D__
# 					 --i--
# 					 2 1
# 					 X 2
# 					 1 1
# 					 sum i counts: 4
# 						 pi 2 0.25 degen: 1 pi_d: 0.25
# 						 pi X 0.1667 degen: 3 pi_d: 0.5
# 						 pi 1 0.25 degen: 1 pi_d: 0.25
# 					 --ij--
# 					 ('2', 'X') 1
# 					 ('1', 'X') 1
# 					 sum pair counts: 2
# 						 pij ('2', 'X') 0.1667 degen: 3 pij_d: 0.5
# 						 pij ('1', 'X') 0.1667 degen: 3 pij_d: 0.5
# 						 pij_max 0.16667
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 0.5
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 1 pA_count 1 pD_count 1
# 						 i 1 N_i 1 ppA_i 0.44444 ppD_i 0.55556 N_i_eff 0.98765 pbias_i 0.24691
# 					 i 2 N_i 1 pA_count 0 pD_count 1
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i ACE_CH3 N_i 1 pA_count 1 pD_count 0
# 					 i X N_i 3 pA_count 2 pD_count 2
# 						 i X N_i 3 ppA_i 0.44444 ppD_i 0.55556 N_i_eff 2.96296 pbias_i 0.24691
# 					 Nc_eff 3.95062
# 					 pbias_ave 0.12346
# 					 S3 (test2) -0.15184
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,2,ACE_C,ARG_CB,X,X,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 X 2
# 					 sum i counts: 3
# 						 pi 0 0.3333 degen: 1 pi_d: 0.3333
# 						 pi X 0.2222 degen: 3 pi_d: 0.6667
# 					 --ij--
# 					 ('0', 'X', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('0', 'X', 'X') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 1.0
# 						 solute_pis 0.333
# 						 largest_pij 1.0
# 						 largest_pi 0.667
# 					 __D__
# 					 --i--
# 					 2 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 2 0.5 degen: 1 pi_d: 0.5
# 						 pi X 0.1667 degen: 3 pi_d: 0.5
# 					 --ij--
# 					 ('2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', 'X') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 5
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 1 pA_count 0 pD_count 0
# 					 i 2 N_i 1 pA_count 0 pD_count 1
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i ARG_CB N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 3 pA_count 2 pD_count 1
# 						 i X N_i 3 ppA_i 0.57143 ppD_i 0.42857 N_i_eff 2.93878 pbias_i 0.2449
# 					 Nc_eff 2.93878
# 					 pbias_ave 0.09184
# 					 S3 (test2) -0.89154
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,ACE_C,ACE_CH3,ARG_N,X,X,X Nc: 8 count: 1 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 0 1
# 					 1 1
# 					 ARG_N 1
# 					 sum i counts: 3
# 						 pi 0 0.3333 degen: 1 pi_d: 0.3333
# 						 pi 1 0.3333 degen: 1 pi_d: 0.3333
# 						 pi ARG_N 0.3333 degen: 1 pi_d: 0.3333
# 					 --ij--
# 					 ('0', '1', 'ARG_N') 1
# 					 sum pair counts: 1
# 						 pij ('0', '1', 'ARG_N') 1.0 degen: 1 pij_d: 1.0
# 						 pij_max 1.0
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 8 4
# 						 solute_pijs 1.0
# 						 solute_pis 0.667
# 						 largest_pij 1.0
# 						 largest_pi 0.333
# 					 __D__
# 					 --i--
# 					 X 2
# 					 sum i counts: 2
# 						 pi X 0.3333 degen: 3 pi_d: 1.0
# 					 --ij--
# 					 ('X', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('X', 'X') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 8 4
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 1.0
# 					 i 0 N_i 1 pA_count 1 pD_count 0
# 					 i 1 N_i 1 pA_count 1 pD_count 0
# 					 i ACE_C N_i 1 pA_count 0 pD_count 0
# 					 i ACE_CH3 N_i 1 pA_count 0 pD_count 0
# 					 i ARG_N N_i 1 pA_count 1 pD_count 0
# 					 i X N_i 3 pA_count 0 pD_count 2
# 					 Nc_eff 0
# 					 pbias_ave 0.0
# 					 S3 (test2) 0
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,2,2,2,ACE_CH3,X Nc: 6 count: 2 / 19
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 2
# 					 ACE_CH3 1
# 					 sum i counts: 3
# 						 pi 2 0.2222 degen: 3 pi_d: 0.6667
# 						 pi ACE_CH3 0.3333 degen: 1 pi_d: 0.3333
# 					 --ij--
# 					 ('2', '2', 'ACE_CH3') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2', 'ACE_CH3') 0.3333 degen: 3 pij_d: 1.0
# 						 pij_max 0.33333
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 6 4
# 						 solute_pijs 1.0
# 						 solute_pis 0.333
# 						 largest_pij 1.0
# 						 largest_pi 0.667
# 					 __D__
# 					 --i--
# 					 2 2
# 					 X 1
# 					 0 1
# 					 sum i counts: 4
# 						 pi 2 0.1667 degen: 3 pi_d: 0.5
# 						 pi X 0.25 degen: 1 pi_d: 0.25
# 						 pi 0 0.25 degen: 1 pi_d: 0.25
# 					 --ij--
# 					 ('2', 'X') 1
# 					 ('0', '2') 1
# 					 sum pair counts: 2
# 						 pij ('2', 'X') 0.1667 degen: 3 pij_d: 0.5
# 						 pij ('0', '2') 0.1667 degen: 3 pij_d: 0.5
# 						 pij_max 0.16667
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 6 4
# 						 solute_pijs 0.5
# 						 solute_pis 0.25
# 						 largest_pij 0.5
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 1
# 					 i 2 N_i 3 pA_count 2 pD_count 2
# 						 i 2 N_i 3 ppA_i 0.57143 ppD_i 0.42857 N_i_eff 2.93878 pbias_i 0.2449
# 					 i ACE_CH3 N_i 1 pA_count 1 pD_count 0
# 					 i X N_i 1 pA_count 0 pD_count 1
# 					 Nc_eff 2.93878
# 					 pbias_ave 0.12245
# 					 S3 (test2) -0.60385
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 			S5 =  0.045
# 		S4 =  0.045
# 	S2 =  0.003
#
#
# nearest: ACE_1_ARG_2 count: 52 / 580
# 	assigned: ('WAT', 2, 'O') count: 52 / 52
# 	N_H 2
# 			shell_num: 0 count: 26 / 52
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,ARG_C,ARG_O,X,X Nc: 9 count: 1 / 26
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 2 2
# 					 X 1
# 					 sum i counts: 3
# 						 pi 2 0.3333 degen: 2 pi_d: 0.6667
# 						 pi X 0.1667 degen: 2 pi_d: 0.3333
# 					 --ij--
# 					 ('2', '2', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('2', '2', 'X') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor False
# 						 Nc, Nc_solvent_only 9 6
# 						 solute_pijs 0
# 						 solute_pis 0
# 						 largest_pij 1.0
# 						 largest_pi 0.667
# 					 __D__
# 					 --i--
# 					 0 1
# 					 X 1
# 					 sum i counts: 2
# 						 pi 0 0.5 degen: 1 pi_d: 0.5
# 						 pi X 0.25 degen: 2 pi_d: 0.5
# 					 --ij--
# 					 ('0', 'X') 1
# 					 sum pair counts: 1
# 						 pij ('0', 'X') 0.5 degen: 2 pij_d: 1.0
# 						 pij_max 0.5
# 						 solute_donor True
# 						 Nc, Nc_solvent_only 9 6
# 						 solute_pijs 1.0
# 						 solute_pis 0.5
# 						 largest_pij 1.0
# 						 largest_pi 0.5
# 					 i 0 N_i 1 pA_count 0 pD_count 1
# 					 i 1 N_i 2 pA_count 0 pD_count 0
# 					 i 2 N_i 2 pA_count 2 pD_count 0
# 					 i ARG_C N_i 1 pA_count 0 pD_count 0
# 					 i ARG_O N_i 1 pA_count 0 pD_count 0
# 					 i X N_i 2 pA_count 1 pD_count 1
# 						 i X N_i 2 ppA_i 0.4 ppD_i 0.6 N_i_eff 1.92 pbias_i 0.24
# 					 Nc_eff 1.92
# 					 pbias_ave 0.05333
# 					 S3 (test2) -2.07349
# 				S7_DA =  0
#
# 				 *** Sor-list:
# 				 0 DA <-- selected Sor
# 				S6 =  0.0
#
# 				 -----RADshell------
# 				neighbours: 0,1,1,2,2,ARG_CA,X Nc: 7 count: 1 / 26
# 				 * SEPARATE ADs *
# 					 __A__
# 					 --i--
# 					 1 1
# 					 2 2
# 					 sum i counts: 3
# 						 pi 1 0.1667 degen: 2 pi_d: 0.3333
# ...
# ARG_2_ARG_2,WAT,1,1,0.42799,0.4003,99
# ARG_2_ARG_2,WAT,1,2,0.57269,0.30966,102
# ARG_2_ARG_2,WAT,1,ACE_C,0.0,0.0,1
# ARG_2_ARG_2,WAT,1,ARG_C,0.0,0.0,4
# ARG_2_ARG_2,WAT,1,ARG_CA,0.0,0.83333,6
# ARG_2_ARG_2,WAT,1,ARG_CB,0.0,0.0,12
# ARG_2_ARG_2,WAT,1,ARG_CD,0.0,0.0,28
# ARG_2_ARG_2,WAT,1,ARG_CG,0.0,0.0,17
# ARG_2_ARG_2,WAT,1,ARG_CZ,0.0,0.0,10
# ARG_2_ARG_2,WAT,1,ARG_N,0.0,0.25,4
# ARG_2_ARG_2,WAT,1,ARG_NE,0.0,0.35294,17
# ARG_2_ARG_2,WAT,1,ARG_NH1,0.0,0.57143,14
# ARG_2_ARG_2,WAT,1,ARG_NH2,0.18182,0.36364,11
# ARG_2_ARG_2,WAT,1,ARG_O,0.0,0.0,7
# ARG_2_ARG_2,WAT,1,NME_N,0.0,0.33333,3
# ARG_2_ARG_2,WAT,1,X,0.46673,0.43571,41
# ARG_2_NME_3,WAT,0,0,0.08571,0.37143,35
# ARG_2_NME_3,WAT,0,1,0.36133,0.35867,25
# ARG_2_NME_3,WAT,0,2,0.57246,0.34058,23
# ARG_2_NME_3,WAT,0,ACE_C,0.0,0.0,1
# ARG_2_NME_3,WAT,0,ACE_CH3,0.0,0.5,4
# ARG_2_NME_3,WAT,0,ARG_C,0.0,0.0,2
# ARG_2_NME_3,WAT,0,ARG_CB,0.0,0.0,6
# ARG_2_NME_3,WAT,0,ARG_CD,0.0,0.0,1
# ARG_2_NME_3,WAT,0,ARG_CG,0.0,0.0,2
# ARG_2_NME_3,WAT,0,ARG_N,0.0,0.5,8
# ARG_2_NME_3,WAT,0,ARG_O,0.0,0.0,3
# ARG_2_NME_3,WAT,0,NME_CH3,0.0,0.0,6
# ARG_2_NME_3,WAT,0,NME_N,0.0,0.61538,13
# ARG_2_NME_3,WAT,0,X,0.57476,0.3681,35
# ARG_2_NME_3,WAT,1,0,0.08571,0.37143,35
# ARG_2_NME_3,WAT,1,1,0.36133,0.35867,25
# ARG_2_NME_3,WAT,1,2,0.57246,0.34058,23
# ARG_2_NME_3,WAT,1,ACE_C,0.0,0.0,1
# ARG_2_NME_3,WAT,1,ACE_CH3,0.0,0.5,4
# ARG_2_NME_3,WAT,1,ARG_C,0.0,0.0,2
# ARG_2_NME_3,WAT,1,ARG_CB,0.0,0.0,6
# ARG_2_NME_3,WAT,1,ARG_CD,0.0,0.0,1
# ARG_2_NME_3,WAT,1,ARG_CG,0.0,0.0,2
# ARG_2_NME_3,WAT,1,ARG_N,0.0,0.5,8
# ARG_2_NME_3,WAT,1,ARG_O,0.0,0.0,3
# ARG_2_NME_3,WAT,1,NME_CH3,0.0,0.0,6
# ARG_2_NME_3,WAT,1,NME_N,0.0,0.61538,13
# ARG_2_NME_3,WAT,1,X,0.57476,0.3681,35
# NME_3_ACE_1,WAT,0,0,0.1875,0.4375,16
# NME_3_ACE_1,WAT,0,1,0.43651,0.34921,14
# NME_3_ACE_1,WAT,0,2,0.54167,0.20833,12
# NME_3_ACE_1,WAT,0,ACE_C,0.0,0.0,5
# NME_3_ACE_1,WAT,0,ACE_CH3,0.0,0.5,8
# NME_3_ACE_1,WAT,0,ACE_O,1.0,0.0,1
# NME_3_ACE_1,WAT,0,ARG_N,0.0,1.0,2
# NME_3_ACE_1,WAT,0,NME_CH3,0.0,0.0,6
# NME_3_ACE_1,WAT,0,NME_N,0.0,0.42857,7
# NME_3_ACE_1,WAT,0,X,0.48194,0.51806,16
# NME_3_ACE_1,WAT,1,0,0.1875,0.4375,16
# NME_3_ACE_1,WAT,1,1,0.43651,0.34921,14
# NME_3_ACE_1,WAT,1,2,0.54167,0.20833,12
# NME_3_ACE_1,WAT,1,ACE_C,0.0,0.0,5
# NME_3_ACE_1,WAT,1,ACE_CH3,0.0,0.5,8
# NME_3_ACE_1,WAT,1,ACE_O,1.0,0.0,1
# NME_3_ACE_1,WAT,1,ARG_N,0.0,1.0,2
# NME_3_ACE_1,WAT,1,NME_CH3,0.0,0.0,6
# NME_3_ACE_1,WAT,1,NME_N,0.0,0.42857,7
# NME_3_ACE_1,WAT,1,X,0.48194,0.51806,16
# NME_3_ARG_2,WAT,0,0,0.08571,0.37143,35
# NME_3_ARG_2,WAT,0,1,0.36133,0.35867,25
# NME_3_ARG_2,WAT,0,2,0.57246,0.34058,23
# NME_3_ARG_2,WAT,0,ACE_C,0.0,0.0,1
# NME_3_ARG_2,WAT,0,ACE_CH3,0.0,0.5,4
# NME_3_ARG_2,WAT,0,ARG_C,0.0,0.0,2
# NME_3_ARG_2,WAT,0,ARG_CB,0.0,0.0,6
# NME_3_ARG_2,WAT,0,ARG_CD,0.0,0.0,1
# NME_3_ARG_2,WAT,0,ARG_CG,0.0,0.0,2
# NME_3_ARG_2,WAT,0,ARG_N,0.0,0.5,8
# NME_3_ARG_2,WAT,0,ARG_O,0.0,0.0,3
# NME_3_ARG_2,WAT,0,NME_CH3,0.0,0.0,6
# NME_3_ARG_2,WAT,0,NME_N,0.0,0.61538,13
# NME_3_ARG_2,WAT,0,X,0.57476,0.3681,35
# NME_3_ARG_2,WAT,1,0,0.08571,0.37143,35
# NME_3_ARG_2,WAT,1,1,0.36133,0.35867,25
# NME_3_ARG_2,WAT,1,2,0.57246,0.34058,23
# NME_3_ARG_2,WAT,1,ACE_C,0.0,0.0,1
# NME_3_ARG_2,WAT,1,ACE_CH3,0.0,0.5,4
# NME_3_ARG_2,WAT,1,ARG_C,0.0,0.0,2
# NME_3_ARG_2,WAT,1,ARG_CB,0.0,0.0,6
# NME_3_ARG_2,WAT,1,ARG_CD,0.0,0.0,1
# NME_3_ARG_2,WAT,1,ARG_CG,0.0,0.0,2
# NME_3_ARG_2,WAT,1,ARG_N,0.0,0.5,8
# NME_3_ARG_2,WAT,1,ARG_O,0.0,0.0,3
# NME_3_ARG_2,WAT,1,NME_CH3,0.0,0.0,6
# NME_3_ARG_2,WAT,1,NME_N,0.0,0.61538,13
# NME_3_ARG_2,WAT,1,X,0.57476,0.3681,35
# NME_3_NME_3,WAT,0,0,0.15385,0.07692,13
# NME_3_NME_3,WAT,0,1,0.33333,0.5,12
# NME_3_NME_3,WAT,0,2,0.58974,0.25641,13
# NME_3_NME_3,WAT,0,ACE_C,0.0,0.0,1
# NME_3_NME_3,WAT,0,ACE_CH3,0.0,0.0,1
# NME_3_NME_3,WAT,0,NME_CH3,0.0,0.0,8
# NME_3_NME_3,WAT,0,NME_N,0.0,0.0,8
# NME_3_NME_3,WAT,0,X,0.47222,0.52778,12
# NME_3_NME_3,WAT,1,0,0.15385,0.07692,13
# NME_3_NME_3,WAT,1,1,0.33333,0.5,12
# NME_3_NME_3,WAT,1,2,0.58974,0.25641,13
# NME_3_NME_3,WAT,1,ACE_C,0.0,0.0,1
# NME_3_NME_3,WAT,1,ACE_CH3,0.0,0.0,1
# NME_3_NME_3,WAT,1,NME_CH3,0.0,0.0,8
# NME_3_NME_3,WAT,1,NME_N,0.0,0.0,8
# NME_3_NME_3,WAT,1,X,0.47222,0.52778,12
#
#
#  --UA_VIBRATIONAL_ENTROPY--
#
#
# nearest ARG_2_NME_3
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 35
#
# 			ave forces:
# 			[663939.55295161 -20099.24591122 -89533.00451361]
# 			[ -20099.24591122 1205290.31679181  208384.33054235]
# 			[-89533.00451361 208384.33054235 974148.98881278]
# 			Strans 5.8952230775617185
#
# 			eigenvalues:
# 			[ 663939.55295161 1205290.31679181  974148.98881278]
#
# 			ave torques:
# 			[5823881.08487861  576316.80734691  871493.33614226]
# 			[ 576316.80734691 9308691.66315525 2682584.89126644]
# 			[  871493.33614226  2682584.89126644 20060044.0762191 ]
# 			Srot 2.4772438786341033
#
# 			eigenvalues:
# 			[ 5823881.08487861  9308691.66315525 20060044.0762191 ]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 35
#
# 			ave forces:
# 			[663939.55295161 -20099.24591122 -89533.00451361]
# 			[ -20099.24591122 1205290.31679181  208384.33054235]
# 			[-89533.00451361 208384.33054235 974148.98881278]
# 			Strans 5.8952230775617185
#
# 			eigenvalues:
# 			[ 663939.55295161 1205290.31679181  974148.98881278]
#
# 			ave torques:
# 			[5823881.08487861  576316.80734691  871493.33614226]
# 			[ 576316.80734691 9308691.66315525 2682584.89126644]
# 			[  871493.33614226  2682584.89126644 20060044.0762191 ]
# 			Srot 2.4772438786341033
#
# 			eigenvalues:
# 			[ 5823881.08487861  9308691.66315525 20060044.0762191 ]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# nearest NME_3_ARG_2
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 35
#
# 			ave forces:
# 			[663939.55295161 -20099.24591122 -89533.00451361]
# 			[ -20099.24591122 1205290.31679181  208384.33054235]
# 			[-89533.00451361 208384.33054235 974148.98881278]
# 			Strans 5.8952230775617185
#
# 			eigenvalues:
# 			[ 663939.55295161 1205290.31679181  974148.98881278]
#
# 			ave torques:
# 			[5823881.08487861  576316.80734691  871493.33614226]
# 			[ 576316.80734691 9308691.66315525 2682584.89126644]
# 			[  871493.33614226  2682584.89126644 20060044.0762191 ]
# 			Srot 2.4772438786341033
#
# 			eigenvalues:
# 			[ 5823881.08487861  9308691.66315525 20060044.0762191 ]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 35
#
# 			ave forces:
# 			[663939.55295161 -20099.24591122 -89533.00451361]
# 			[ -20099.24591122 1205290.31679181  208384.33054235]
# 			[-89533.00451361 208384.33054235 974148.98881278]
# 			Strans 5.8952230775617185
#
# 			eigenvalues:
# 			[ 663939.55295161 1205290.31679181  974148.98881278]
#
# 			ave torques:
# 			[5823881.08487861  576316.80734691  871493.33614226]
# 			[ 576316.80734691 9308691.66315525 2682584.89126644]
# 			[  871493.33614226  2682584.89126644 20060044.0762191 ]
# 			Srot 2.4772438786341033
#
# 			eigenvalues:
# 			[ 5823881.08487861  9308691.66315525 20060044.0762191 ]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# nearest ARG_2_ARG_2
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 104
#
# 			ave forces:
# 			[ 856785.4605881  -328285.81980907  -23562.78808847]
# 			[-328285.81980907 1401273.13788743  -48215.66957604]
# 			[-23562.78808847 -48215.66957604 916908.30421597]
# 			Strans 5.72486071313245
#
# 			eigenvalues:
# 			[ 856785.4605881  1401273.13788743  916908.30421597]
#
# 			ave torques:
# 			[ 8351009.87279642   656068.51958777 -1553271.28928136]
# 			[ 656068.51958777 5169753.96972544  208543.25258369]
# 			[-1553271.28928136   208543.25258369 11608656.16714355]
# 			Srot 2.804683445310462
#
# 			eigenvalues:
# 			[ 8351009.87279642  5169753.96972544 11608656.16714355]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 104
#
# 			ave forces:
# 			[ 856785.4605881  -328285.81980907  -23562.78808847]
# 			[-328285.81980907 1401273.13788743  -48215.66957604]
# 			[-23562.78808847 -48215.66957604 916908.30421597]
# 			Strans 5.72486071313245
#
# 			eigenvalues:
# 			[ 856785.4605881  1401273.13788743  916908.30421597]
#
# 			ave torques:
# 			[ 8351009.87279642   656068.51958777 -1553271.28928136]
# 			[ 656068.51958777 5169753.96972544  208543.25258369]
# 			[-1553271.28928136   208543.25258369 11608656.16714355]
# 			Srot 2.804683445310462
#
# 			eigenvalues:
# 			[ 8351009.87279642  5169753.96972544 11608656.16714355]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# nearest ACE_1_ACE_1
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 19
#
# 			ave forces:
# 			[584902.04418241  41002.81136304  35035.98433633]
# 			[ 41002.81136304 389067.72125448 -97305.17920482]
# 			[ 35035.98433633 -97305.17920482 829847.94340711]
# 			Strans 6.597245746495474
#
# 			eigenvalues:
# 			[584902.04418241 389067.72125448 829847.94340711]
#
# 			ave torques:
# 			[9480370.17205417  405438.24668674  118112.57601591]
# 			[ 405438.24668674 6074688.89988559 4009860.7575142 ]
# 			[  118112.57601591  4009860.7575142  12968516.05364318]
# 			Srot 2.6262160725857724
#
# 			eigenvalues:
# 			[ 9480370.17205417  6074688.89988559 12968516.05364318]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 19
#
# 			ave forces:
# 			[584902.04418241  41002.81136304  35035.98433633]
# 			[ 41002.81136304 389067.72125448 -97305.17920482]
# 			[ 35035.98433633 -97305.17920482 829847.94340711]
# 			Strans 6.597245746495474
#
# 			eigenvalues:
# 			[584902.04418241 389067.72125448 829847.94340711]
#
# 			ave torques:
# 			[9480370.17205417  405438.24668674  118112.57601591]
# 			[ 405438.24668674 6074688.89988559 4009860.7575142 ]
# 			[  118112.57601591  4009860.7575142  12968516.05364318]
# 			Srot 2.6262160725857724
#
# 			eigenvalues:
# 			[ 9480370.17205417  6074688.89988559 12968516.05364318]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# nearest ACE_1_ARG_2
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 26
#
# 			ave forces:
# 			[ 495181.91432417  -91567.84552529 -132823.6880147 ]
# 			[-91567.84552529 864695.62550985 125332.78978492]
# 			[-132823.6880147   125332.78978492  616825.15721979]
# 			Strans 6.4306669151160225
#
# 			eigenvalues:
# 			[495181.91432417 864695.62550985 616825.15721979]
#
# 			ave torques:
# 			[ 9876805.21819764    57355.68346089 -5713319.26030244]
# 			[   57355.68346089  6871613.37463941 -1869370.42391062]
# 			[-5713319.26030244 -1869370.42391062 12021661.80984246]
# 			Srot 2.58377325396415
#
# 			eigenvalues:
# 			[ 9876805.21819764  6871613.37463941 12021661.80984246]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 26
#
# 			ave forces:
# 			[ 495181.91432417  -91567.84552529 -132823.6880147 ]
# 			[-91567.84552529 864695.62550985 125332.78978492]
# 			[-132823.6880147   125332.78978492  616825.15721979]
# 			Strans 6.4306669151160225
#
# 			eigenvalues:
# 			[495181.91432417 864695.62550985 616825.15721979]
#
# 			ave torques:
# 			[ 9876805.21819764    57355.68346089 -5713319.26030244]
# 			[   57355.68346089  6871613.37463941 -1869370.42391062]
# 			[-5713319.26030244 -1869370.42391062 12021661.80984246]
# 			Srot 2.58377325396415
#
# 			eigenvalues:
# 			[ 9876805.21819764  6871613.37463941 12021661.80984246]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# nearest ARG_2_ACE_1
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 26
#
# 			ave forces:
# 			[ 495181.91432417  -91567.84552529 -132823.6880147 ]
# 			[-91567.84552529 864695.62550985 125332.78978492]
# 			[-132823.6880147   125332.78978492  616825.15721979]
# 			Strans 6.4306669151160225
#
# 			eigenvalues:
# 			[495181.91432417 864695.62550985 616825.15721979]
#
# 			ave torques:
# 			[ 9876805.21819764    57355.68346089 -5713319.26030244]
# 			[   57355.68346089  6871613.37463941 -1869370.42391062]
# 			[-5713319.26030244 -1869370.42391062 12021661.80984246]
# 			Srot 2.58377325396415
#
# 			eigenvalues:
# 			[ 9876805.21819764  6871613.37463941 12021661.80984246]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 26
#
# 			ave forces:
# 			[ 495181.91432417  -91567.84552529 -132823.6880147 ]
# 			[-91567.84552529 864695.62550985 125332.78978492]
# 			[-132823.6880147   125332.78978492  616825.15721979]
# 			Strans 6.4306669151160225
#
# 			eigenvalues:
# 			[495181.91432417 864695.62550985 616825.15721979]
#
# 			ave torques:
# 			[ 9876805.21819764    57355.68346089 -5713319.26030244]
# 			[   57355.68346089  6871613.37463941 -1869370.42391062]
# 			[-5713319.26030244 -1869370.42391062 12021661.80984246]
# 			Srot 2.58377325396415
#
# 			eigenvalues:
# 			[ 9876805.21819764  6871613.37463941 12021661.80984246]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# nearest NME_3_NME_3
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 13
#
# 			ave forces:
# 			[ 7.65189664e+05  4.34447566e-11 -8.89963431e+04]
# 			[ 4.34447566e-11  1.08114904e+06 -3.60010333e+05]
# 			[ -88996.3431479  -360010.33283446 1197202.06335137]
# 			Strans 5.776838315353443
#
# 			eigenvalues:
# 			[ 765189.66395002 1081149.0430153  1197202.06335137]
#
# 			ave torques:
# 			[11858650.92000623  -634825.67386151 -2446505.00095767]
# 			[-634825.67386151 3756853.16891416 -757810.57017142]
# 			[-2446505.00095767  -757810.57017142 16004359.97016209]
# 			Srot 2.6671936633930082
#
# 			eigenvalues:
# 			[11858650.92000623  3756853.16891416 16004359.97016209]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 13
#
# 			ave forces:
# 			[ 7.65189664e+05  4.34447566e-11 -8.89963431e+04]
# 			[ 4.34447566e-11  1.08114904e+06 -3.60010333e+05]
# 			[ -88996.3431479  -360010.33283446 1197202.06335137]
# 			Strans 5.776838315353443
#
# 			eigenvalues:
# 			[ 765189.66395002 1081149.0430153  1197202.06335137]
#
# 			ave torques:
# 			[11858650.92000623  -634825.67386151 -2446505.00095767]
# 			[-634825.67386151 3756853.16891416 -757810.57017142]
# 			[-2446505.00095767  -757810.57017142 16004359.97016209]
# 			Srot 2.6671936633930082
#
# 			eigenvalues:
# 			[11858650.92000623  3756853.16891416 16004359.97016209]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# nearest ACE_1_NME_3
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 16
#
# 			ave forces:
# 			[ 756524.81898273  -75761.49123818 -168056.06569621]
# 			[ -75761.49123818 1039404.05605192 -226012.69808226]
# 			[-168056.06569621 -226012.69808226  939660.5100333 ]
# 			Strans 5.921301155876144
#
# 			eigenvalues:
# 			[ 756524.81898273 1039404.05605192  939660.5100333 ]
#
# 			ave torques:
# 			[3950861.84284305 -347921.47654945  257625.40665646]
# 			[-347921.47654945 4971552.6288769  -663866.88005833]
# 			[  257625.40665646  -663866.88005833 12673062.49359301]
# 			Srot 3.1318738605853005
#
# 			eigenvalues:
# 			[ 3950861.84284305  4971552.6288769  12673062.49359301]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 16
#
# 			ave forces:
# 			[ 756524.81898273  -75761.49123818 -168056.06569621]
# 			[ -75761.49123818 1039404.05605192 -226012.69808226]
# 			[-168056.06569621 -226012.69808226  939660.5100333 ]
# 			Strans 5.921301155876144
#
# 			eigenvalues:
# 			[ 756524.81898273 1039404.05605192  939660.5100333 ]
#
# 			ave torques:
# 			[3950861.84284305 -347921.47654945  257625.40665646]
# 			[-347921.47654945 4971552.6288769  -663866.88005833]
# 			[  257625.40665646  -663866.88005833 12673062.49359301]
# 			Srot 3.1318738605853005
#
# 			eigenvalues:
# 			[ 3950861.84284305  4971552.6288769  12673062.49359301]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# nearest NME_3_ACE_1
# 	assigned ('WAT', 2, 'O')
#
# 		RADshell_num 1.0 count 16
#
# 			ave forces:
# 			[ 756524.81898273  -75761.49123818 -168056.06569621]
# 			[ -75761.49123818 1039404.05605192 -226012.69808226]
# 			[-168056.06569621 -226012.69808226  939660.5100333 ]
# 			Strans 5.921301155876144
#
# 			eigenvalues:
# 			[ 756524.81898273 1039404.05605192  939660.5100333 ]
#
# 			ave torques:
# 			[3950861.84284305 -347921.47654945  257625.40665646]
# 			[-347921.47654945 4971552.6288769  -663866.88005833]
# 			[  257625.40665646  -663866.88005833 12673062.49359301]
# 			Srot 3.1318738605853005
#
# 			eigenvalues:
# 			[ 3950861.84284305  4971552.6288769  12673062.49359301]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
# 		RADshell_num 0.0 count 16
#
# 			ave forces:
# 			[ 756524.81898273  -75761.49123818 -168056.06569621]
# 			[ -75761.49123818 1039404.05605192 -226012.69808226]
# 			[-168056.06569621 -226012.69808226  939660.5100333 ]
# 			Strans 5.921301155876144
#
# 			eigenvalues:
# 			[ 756524.81898273 1039404.05605192  939660.5100333 ]
#
# 			ave torques:
# 			[3950861.84284305 -347921.47654945  257625.40665646]
# 			[-347921.47654945 4971552.6288769  -663866.88005833]
# 			[  257625.40665646  -663866.88005833 12673062.49359301]
# 			Srot 3.1318738605853005
#
# 			eigenvalues:
# 			[ 3950861.84284305  4971552.6288769  12673062.49359301]
#
# 			ave pe:  0.0
#
# 			ave ke:  0.0
#
#
#  --WM_VIBRATIONAL_ENTROPY--
#
#
#
#  --WM_CONFORMATIONAL_ENTROPY(DIH)--
#
#
#
# --PRINT_ALL_VARIABLES--
# 0:00:00.729022

# %%
print(result_solcon)
# Out:
# {'soluteContacts': {'solventData':         nearest assigned  shell_num   variable      value count
# 0   ACE_1_ACE_1      WAT        1.0  Sor_test2   0.747622    19
# 1   ACE_1_ACE_1      WAT        1.0     Strans  54.849501    19
# 2   ACE_1_ACE_1      WAT        1.0       Srot  21.834360    19
# 3   ACE_1_ACE_1      WAT        1.0      count   0.950000    19
# 4   ACE_1_ARG_2      WAT        1.0  Sor_test2   0.129079    26
# 5   ACE_1_ARG_2      WAT        1.0     Strans  53.464565    26
# 6   ACE_1_ARG_2      WAT        1.0       Srot  21.481491    26
# 7   ACE_1_ARG_2      WAT        1.0      count   1.300000    26
# 8   ACE_1_NME_3      WAT        1.0  Sor_test2   0.029043    16
# 9   ACE_1_NME_3      WAT        1.0     Strans  49.229698    16
# 10  ACE_1_NME_3      WAT        1.0       Srot  26.038399    16
# 11  ACE_1_NME_3      WAT        1.0      count   0.800000    16
# 12  ARG_2_ACE_1      WAT        1.0  Sor_test2   0.129079    26
# 13  ARG_2_ACE_1      WAT        1.0     Strans  53.464565    26
# 14  ARG_2_ACE_1      WAT        1.0       Srot  21.481491    26
# 15  ARG_2_ACE_1      WAT        1.0      count   1.300000    26
# 16  ARG_2_ARG_2      WAT        1.0  Sor_test2   0.424278   104
# 17  ARG_2_ARG_2      WAT        1.0     Strans  47.596492   104
# 18  ARG_2_ARG_2      WAT        1.0       Srot  23.318138   104
# 19  ARG_2_ARG_2      WAT        1.0      count   5.200000   104
# 20  ARG_2_NME_3      WAT        1.0  Sor_test2   0.733499    35
# 21  ARG_2_NME_3      WAT        1.0     Strans  49.012885    35
# 22  ARG_2_NME_3      WAT        1.0       Srot  20.595806    35
# 23  ARG_2_NME_3      WAT        1.0      count   1.750000    35
# 24  NME_3_ACE_1      WAT        1.0  Sor_test2   0.029043    16
# 25  NME_3_ACE_1      WAT        1.0     Strans  49.229698    16
# 26  NME_3_ACE_1      WAT        1.0       Srot  26.038399    16
# 27  NME_3_ACE_1      WAT        1.0      count   0.800000    16
# 28  NME_3_ARG_2      WAT        1.0  Sor_test2   0.733499    35
# 29  NME_3_ARG_2      WAT        1.0     Strans  49.012885    35
# 30  NME_3_ARG_2      WAT        1.0       Srot  20.595806    35
# 31  NME_3_ARG_2      WAT        1.0      count   1.750000    35
# 32  NME_3_NME_3      WAT        1.0  Sor_test2   0.015884    13
# 33  NME_3_NME_3      WAT        1.0     Strans  48.028634    13
# 34  NME_3_NME_3      WAT        1.0       Srot  22.175048    13
# 35  NME_3_NME_3      WAT        1.0      count   0.650000    13, 'soluteData': Empty DataFrame
# Columns: [resName, variable, value, count]
# Index: []}}

# %%
solcon_df=result_solcon['soluteContacts']['solventData']

# %%
solcon_df
# Out:
#         nearest assigned  shell_num   variable      value count
# 0   ACE_1_ACE_1      WAT        1.0  Sor_test2   0.747622    19
# 1   ACE_1_ACE_1      WAT        1.0     Strans  54.849501    19
# 2   ACE_1_ACE_1      WAT        1.0       Srot  21.834360    19
# 3   ACE_1_ACE_1      WAT        1.0      count   0.950000    19
# 4   ACE_1_ARG_2      WAT        1.0  Sor_test2   0.129079    26
# 5   ACE_1_ARG_2      WAT        1.0     Strans  53.464565    26
# 6   ACE_1_ARG_2      WAT        1.0       Srot  21.481491    26
# 7   ACE_1_ARG_2      WAT        1.0      count   1.300000    26
# 8   ACE_1_NME_3      WAT        1.0  Sor_test2   0.029043    16
# 9   ACE_1_NME_3      WAT        1.0     Strans  49.229698    16
# 10  ACE_1_NME_3      WAT        1.0       Srot  26.038399    16
# 11  ACE_1_NME_3      WAT        1.0      count   0.800000    16
# 12  ARG_2_ACE_1      WAT        1.0  Sor_test2   0.129079    26
# 13  ARG_2_ACE_1      WAT        1.0     Strans  53.464565    26
# 14  ARG_2_ACE_1      WAT        1.0       Srot  21.481491    26
# 15  ARG_2_ACE_1      WAT        1.0      count   1.300000    26
# 16  ARG_2_ARG_2      WAT        1.0  Sor_test2   0.424278   104
# 17  ARG_2_ARG_2      WAT        1.0     Strans  47.596492   104
# 18  ARG_2_ARG_2      WAT        1.0       Srot  23.318138   104
# 19  ARG_2_ARG_2      WAT        1.0      count   5.200000   104
# 20  ARG_2_NME_3      WAT        1.0  Sor_test2   0.733499    35
# 21  ARG_2_NME_3      WAT        1.0     Strans  49.012885    35
# 22  ARG_2_NME_3      WAT        1.0       Srot  20.595806    35
# 23  ARG_2_NME_3      WAT        1.0      count   1.750000    35
# 24  NME_3_ACE_1      WAT        1.0  Sor_test2   0.029043    16
# 25  NME_3_ACE_1      WAT        1.0     Strans  49.229698    16
# 26  NME_3_ACE_1      WAT        1.0       Srot  26.038399    16
# 27  NME_3_ACE_1      WAT        1.0      count   0.800000    16
# 28  NME_3_ARG_2      WAT        1.0  Sor_test2   0.733499    35
# 29  NME_3_ARG_2      WAT        1.0     Strans  49.012885    35
# 30  NME_3_ARG_2      WAT        1.0       Srot  20.595806    35
# 31  NME_3_ARG_2      WAT        1.0      count   1.750000    35
# 32  NME_3_NME_3      WAT        1.0  Sor_test2   0.015884    13
# 33  NME_3_NME_3      WAT        1.0     Strans  48.028634    13
# 34  NME_3_NME_3      WAT        1.0       Srot  22.175048    13
# 35  NME_3_NME_3      WAT        1.0      count   0.650000    13

# %%
solcon_df.to_csv('solcon.csv')
